# %%
import xarray as xr

# %%
analogues = xr.open_dataset("/work/fl53wumy-dpa_data/fl53wumy-llaae_data_new_22092025-1763346001/fl53wumy-llaae_data_new-1758244802/fl53wumy-llaae_data_new-1748049607/analogues/analogue_ensemble_10pcs_5analogues_100analoguemembers_v4_data_complete.nc")
analogues
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:                   (lat: 32, lon: 32, time: 14307, analogue: 5,
#                                analogue_ensemble_member: 100)
# Coordinates:
#   * lat                       (lat) float64 256B 34.4 35.34 ... 62.67 63.61
#   * lon                       (lon) float64 256B -11.25 -10.0 ... 26.25 27.5
#   * time                      (time) object 114kB 1850-06-02 00:00:00 ... 210...
#   * analogue                  (analogue) int64 40B 0 1 2 3 4
#   * analogue_ensemble_member  (analogue_ensemble_member) int64 800B 0 1 ... 99
# Data variables:
#     true_temp                 (lat, lon, time) float32 59MB ...
#     analogue_temp             (time, analogue, lat, lon) float32 293MB ...
#     analogue_time             (time, analogue) object 572kB ...
#     ensemble_temp             (time, analogue_ensemble_member, lat, lon) float32 6GB ...

# %%
analogues.analogue_time
# Out:
# <xarray.DataArray 'analogue_time' (time: 14307, analogue: 5)> Size: 572kB
# [71535 values with dtype=object]
# Coordinates:
#   * time      (time) object 114kB 1850-06-02 00:00:00 ... 2100-08-31 00:00:00
#   * analogue  (analogue) int64 40B 0 1 2 3 4
