# %%
import xarray as xr

# %%
ds_clim = xr.open_dataset("/work/fl53wumy-dpa_data/fl53wumy-llaae_data_new_22092025-1763346001/fl53wumy-llaae_data_new-1758244802/fl53wumy-llaae_data_new-1748049607/dpa_input_data/eth_test_trefht_data/TREFHT_day_b.e212.BHISTcmip6_BSSP370cmip6.f09_g17.1300_1850-2100_clim.nc")
ds_clim
# Out:
# <xarray.Dataset> Size: 16MB
# Dimensions:  (time: 73, lon: 288, lat: 192)
# Coordinates:
#   * time     (time) object 584B 1900-01-03 00:00:00 ... 1900-12-29 00:00:00
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
# Data variables:
#     TREFHT   (time, lat, lon) float32 16MB ...
# Attributes:
#     CDI:               Climate Data Interface version 2.2.4 (https://mpimet.m...
#     Conventions:       CF-1.0
#     source:            CAM
#     history:           Fri Oct 17 11:36:47 2025: cdo ydaymean temp_ref.nc /cl...
#     case:              b.e212.BHISTcmip6.f09_g17.1300
#     logname:           beyerleu
#     initial_file:      b.e212.B1850cmip6.f09_g17.001.cam.i.1300-01-01-00000.nc
#     topography_file:   /cluster/work/climate/cesm/inputdata/atm/cam/topo/fv_0...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  day_1
#     CDO:               Climate Data Operators version 2.2.2 (https://mpimet.m...

# %%
ds_clim.TREFHT.isel(lat = 10, lon = 11).plot()
