# %%
import xarray as xr

# %%
era5_trefht_fact = xr.open_dataset("ERA5_europe_10percent_masked_stacked_TREFHT_JJA.nc")
era5_trefht_fact
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (lat: 32, lon: 32, time: 1596)
# Coordinates:
#   * lon      (lon) float64 256B -11.25 -10.0 -8.75 -7.5 ... 25.0 26.25 27.5
#   * lat      (lat) float64 256B 34.4 35.34 36.28 37.23 ... 61.73 62.67 63.61
#   * time     (time) object 13kB 1940-06-02 11:30:00 ... 2023-08-31 11:30:00
# Data variables:
#     TREFHT   (lat, lon, time) float32 7MB ...

# %%
era5_trefht_cf = xr.open_dataset("ERA5_nudged_europe_10percent_masked_TREFHT_JJA.nc")
era5_trefht_cf
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (time: 1615, lat: 32, lon: 32)
# Coordinates:
#   * lon      (lon) float64 256B -11.25 -10.0 -8.75 -7.5 ... 25.0 26.25 27.5
#   * lat      (lat) float64 256B 34.4 35.34 36.28 37.23 ... 61.73 62.67 63.61
#   * time     (time) object 13kB 1940-06-02 00:00:00 ... 2024-08-31 00:00:00
# Data variables:
#     TREFHT   (time, lat, lon) float32 7MB ...

# %%
era5_trefht_cf_short = era5_trefht_cf.sel(time=slice("1940","2023"))
era5_trefht_cf_short
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (time: 1596, lat: 32, lon: 32)
# Coordinates:
#   * lon      (lon) float64 256B -11.25 -10.0 -8.75 -7.5 ... 25.0 26.25 27.5
#   * lat      (lat) float64 256B 34.4 35.34 36.28 37.23 ... 61.73 62.67 63.61
#   * time     (time) object 13kB 1940-06-02 00:00:00 ... 2023-08-31 00:00:00
# Data variables:
#     TREFHT   (time, lat, lon) float32 7MB ...

# %%
#era5_trefht_cf_short.to_netcdf("ERA5_nudged_europe_10percent_masked_TREFHT_JJA.nc")
era5_trefht_cf_short = xr.open_dataset("ERA5_nudged_europe_10percent_masked_TREFHT_JJA.nc")
era5_trefht_cf_short
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (time: 1596, lat: 32, lon: 32)
# Coordinates:
#   * lon      (lon) float64 256B -11.25 -10.0 -8.75 -7.5 ... 25.0 26.25 27.5
#   * lat      (lat) float64 256B 34.4 35.34 36.28 37.23 ... 61.73 62.67 63.61
#   * time     (time) object 13kB 1940-06-02 00:00:00 ... 2023-08-31 00:00:00
# Data variables:
#     TREFHT   (time, lat, lon) float32 7MB ...
